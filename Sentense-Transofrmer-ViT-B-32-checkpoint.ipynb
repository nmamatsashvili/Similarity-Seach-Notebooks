# %%
print("start application")
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('clip-ViT-B-32')
print("ViT model imported")
# Out:
# start application
# ViT model imported

# %%
print("insert data")
import os
import time

lstResultSimilarity = []
stmtIds = []
stmtIdsUnvisited = []
start = time.perf_counter()

dir = "C:/Users/nmamatsashvili/source/repos/WebScraping/ParserApp/bin/Debug/net6.0/responses_test_5"
dataFile = "data5.txt"
FileExists = os.path.exists(dataFile)

if FileExists :
    file = open(dataFile,"r+")
    file.truncate()
    file.close()
# Out:
# insert data

# %%
print("get all statement IDs")
for folder in os.listdir(dir):
    stmtIds.append(folder)
stmtIdsUnvisited = list(stmtIds)
openFile = open(dataFile, "a")
end = time.perf_counter()
print("time before iteration: " + str( round(end - start, 2)) + " seconds")
start = time.perf_counter()
# Out:
# get all statement IDs
# time before iteration: 0.05 seconds

# %%
print("iterate over each statement pictures to find similarity")
from PIL import Image
import os
import time
from sentence_transformers import SentenceTransformer, util

for stmt in stmtIds:
    stmtIdsUnvisited.remove(stmt)
    lstImagesCurrent = []
    
    for image in os.listdir(dir + "/" + stmt):
        if os.fsdecode(image).endswith(".jpg") == False:
            continue
        lstImagesCurrent.append(Image.open(f"{dir}/{stmt}/{image}"))

    imgEmbeddingsCurrentBatch = model.encode(lstImagesCurrent)
    indx = 0
    for img_emb in imgEmbeddingsCurrentBatch:
        
        for stmtNext in stmtIdsUnvisited:
            lstImagesNext = []
            for imageNext in os.listdir(dir + "/" + stmtNext):
                if os.fsdecode(imageNext).endswith(".jpg") == False:
                    continue
                lstImagesNext.append(Image.open(f"{dir}/{stmtNext}/{imageNext}")) 
            imgEmbeddingsNextBatch = model.encode(lstImagesNext) 
            indxNext = 0
            for embNext in imgEmbeddingsNextBatch:
                cos_scores = util.cos_sim(img_emb, embNext)
                img = os.listdir(dir + "/" + stmt)[indx]
                imgNxt = os.listdir(dir + "/" + stmtNext)[indxNext]
                result = f"statements: {stmt} vs {stmtNext} - images: {img} vs {imgNxt} - cos_score: {cos_scores}" 
                lstResultSimilarity.append({"id1":stmt, "id2":stmtNext, "img1":img, "img2":imgNxt, "cos_score":cos_scores})
                

                openFile.write("\n" + result)
                indxNext += 1
        indx += 1
print("end iteration")
# Out:
# iterate over each statement pictures to find similarity
# end iteration

# %%
openFile.close()
end = time.perf_counter()
print("total time: " + str( round(end - start, 2)) + " seconds")
print("result lenght: " + str(len(lstResultSimilarity)))
print(lstResultSimilarity)
# Out:
# total time: 135.89 seconds
# result lenght: 695
# [{'id1': '11_5096981', 'id2': '22_5098896', 'img1': '1.jpg', 'img2': '1.jpg', 'cos_score': tensor([[0.7129]])}, {'id1': '11_5096981', 'id2': '22_5098896', 'img1': '1.jpg', 'img2': '2.jpg', 'cos_score': tensor([[0.6966]])}, {'id1': '11_5096981', 'id2': '22_5098896', 'img1': '1.jpg', 'img2': '3.jpg', 'cos_score': tensor([[0.5665]])}, {'id1': '11_5096981', 'id2': '22_5098896', 'img1': '1.jpg', 'img2': '4.jpg', 'cos_score': tensor([[0.7361]])}, {'id1': '11_5096981', 'id2': '22_5098896', 'img1': '1.jpg', 'img2': '5.jpg', 'cos_score': tensor([[0.6313]])}, {'id1': '11_5096981', 'id2': '22_5098896', 'img1': '1.jpg', 'img2': '6.jpg', 'cos_score': tensor([[0.7042]])}, {'id1': '11_5096981', 'id2': '33_5099944', 'img1': '1.jpg', 'img2': '1.jpg', 'cos_score': tensor([[0.7792]])}, {'id1': '11_5096981', 'id2': '33_5099944', 'img1': '1.jpg', 'img2': '2.jpg', 'cos_score': tensor([[0.7716]])}, {'id1': '11_5096981', 'id2': '33_5099944', 'img1': '1.jpg', 'img2': '3.jpg', 'cos_score': tensor([[0.7460]])}, {'id1': '11_5096981', 'id2': '33_5099944', 'img1': '1.jpg', 'img2': '4.jpg', 'cos_score': tensor([[0.7902]])}, {'id1': '11_5096981', 'id2': '33_5099944', 'img1': '1.jpg', 'img2': '5.jpg', 'cos_score': tensor([[0.7226]])}, {'id1': '11_5096981', 'id2': '33_5099944', 'img1': '1.jpg', 'img2': '6.jpg', 'cos_score': tensor([[0.8122]])}, {'id1': '11_5096981', 'id2': '44_5100573', 'img1': '1.jpg', 'img2': '1.jpg', 'cos_score': tensor([[0.7201]])}, {'id1': '11_5096981', 'id2': '44_5100573', 'img1': '1.jpg', 'img2': '10.jpg', 'cos_score': tensor([[0.6925]])}, {'id1': '11_5096981', 'id2': '44_5100573', 'img1': '1.jpg', 'img2': '11.jpg', 'cos_score': tensor([[0.7218]])}, {'id1': '11_5096981', 'id2': '44_5100573', 'img1': '1.jpg', 'img2': '2.jpg', 'cos_score': tensor([[0.7734]])}, {'id1': '11_5096981', 'id2': '44_5100573', 'img1': '1.jpg', 'img2': '3.jpg', 'cos_score': tensor([[0.6383]])}, {'id1': '11_5096981', 'id2': '44_5100573', 'img1': '1.jpg', 'img2': '4.jpg', 'cos_score': tensor([[0.7804]])}, {'id1': '11_5096981', 'id2': '44_5100573', 'img1': '1.jpg', 'img2': '5.jpg', 'cos_score': tensor([[0.6809]])}, {'id1': '11_5096981', 'id2': '44_5100573', 'img1': '1.jpg', 'img2': '6.jpg', 'cos_score': tensor([[0.6971]])}, {'id1': '11_5096981', 'id2': '44_5100573', 'img1': '1.jpg', 'img2': '7.jpg', 'cos_score': tensor([[0.7046]])}, {'id1': '11_5096981', 'id2': '44_5100573', 'img1': '1.jpg', 'img2': '8.jpg', 'cos_score': tensor([[0.7124]])}, {'id1': '11_5096981', 'id2': '44_5100573', 'img1': '1.jpg', 'img2': '9.jpg', 'cos_score': tensor([[0.7559]])}, {'id1': '11_5096981', 'id2': '55_5100792', 'img1': '1.jpg', 'img2': '1.jpg', 'cos_score': tensor([[0.7397]])}, {'id1': '11_5096981', 'id2': '55_5100792', 'img1': '1.jpg', 'img2': '10.jpg', 'cos_score': tensor([[0.6069]])}, {'id1': '11_5096981', 'id2': '55_5100792', 'img1': '1.jpg', 'img2': '2.jpg', 'cos_score': tensor([[0.6608]])}, {'id1': '11_5096981', 'id2': '55_5100792', 'img1': '1.jpg', 'img2': '3.jpg', 'cos_score': tensor([[0.6766]])}, {'id1': '11_5096981', 'id2': '55_5100792', 'img1': '1.jpg', 'img2': '4.jpg', 'cos_score': tensor([[0.7203]])}, {'id1': '11_5096981', 'id2': '55_5100792', 'img1': '1.jpg', 'img2': '5.jpg', 'cos_score': tensor([[0.6297]])}, {'id1': '11_5096981', 'id2': '55_5100792', 'img1': '1.jpg', 'img2': '6.jpg', 'cos_score': tensor([[0.6976]])}, {'id1': '11_5096981', 'id2': '55_5100792', 'img1': '1.jpg', 'img2': '7.jpg', 'cos_score': tensor([[0.7088]])}, {'id1': '11_5096981', 'id2': '55_5100792', 'img1': '1.jpg', 'img2': '8.jpg', 'cos_score': tensor([[0.7162]])}, {'id1': '11_5096981', 'id2': '55_5100792', 'img1': '1.jpg', 'img2': '9.jpg', 'cos_score': tensor([[0.7381]])}, {'id1': '11_5096981', 'id2': '22_5098896', 'img1': '2.jpg', 'img2': '1.jpg', 'cos_score': tensor([[0.7191]])}, {'id1': '11_5096981', 'id2': '22_5098896', 'img1': '2.jpg', 'img2': '2.jpg', 'cos_score': tensor([[0.7030]])}, {'id1': '11_5096981', 'id2': '22_5098896', 'img1': '2.jpg', 'img2': '3.jpg', 'cos_score': tensor([[0.5811]])},  ...
